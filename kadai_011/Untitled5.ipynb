# %%
planets = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# forループで出力
for planet in planets:
    print(planet)
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥

# %%
planets = ["水", "金", "地", "火", "木", "土", "天", "海", "冥"]

# whileループで出力
i = 0
while i < len(planets):
    print(planets[i])
    i += 1
# Out:
# 水
# 金
# 地
# 火
# 木
# 土
# 天
# 海
# 冥
